# %%
# Import Library

import json
import pandas as pd
import re
import numpy as np

# %%
dummy_csv = pd.read_csv('./dummy - 3 lines.csv')

dummy_csv
# Out:
#   api argument 1 argument 2  argument 3  argument 4  return_value
# 0   A       argA        NaN         NaN         NaN           NaN
# 1   B       argA    numberB         NaN         NaN  new_pid=1234
# 2   C    numberB        NaN         NaN         NaN           NaN

# %%
dummy_csv = dummy_csv.fillna('Nothing')

# %%
print(dummy_csv['argument 1'][0])
print(dummy_csv['argument 1'][2])
# Out:
# argA
# numberB

# %%
sequence_dict = {
    'sequence' : [],
    'api start' : [],
    'api list' : [],
    'which argument' :[],
    'which argument index' : []
}
total_argument = 4

# %%
index = 0
seq = 1
for api in dummy_csv['api']:
#     index = 0
    api_list = []
    arg_list = []
    arg_index_list = []
#     api_list.append(api)
    print(api_list)
    print(api)
    for args in range(total_argument):
        
        argument_name = 'argument ' + str(args+1)
        
        arg = dummy_csv[argument_name][index]
        
        print(arg)
        
        
        print('=============== LAGI DI ', arg, '===========')
        if arg == 'Nothing':
            print('SORRY ini nothing, ga bisa')
#             index += 1
            continue
    
        for i in range(len(dummy_csv['argument 1'])):
    #         print(i+1)
            if i < index:
                print('index', i+1, 'ga bisa ya')
                continue
    #         print(arg , dummy_csv['argument 1'][i])
    
    
            for j in range(total_argument):
                print('argument ' + str(j+1))
                print(arg, 'bandingkan dengan', dummy_csv['argument ' + str(j+1)][i])
                if dummy_csv['argument ' + str(j+1)][i]=='Nothing':
    #                 print('NOTHING nih ngab')
                    continue
                if arg==dummy_csv['argument ' + str(j+1)][i]:
                    api_list.append(dummy_csv['api'][i])
                    arg_list.append('argument ' + str(j+1))
                    arg_index_list.append(i)
                    print('YEY sama guys')
    #                 print(api_list)
                else:
                    print('WADUH gak sama guys')

            if i+1 ==len(dummy_csv['argument 1']):
                print('mentok bos')
                print('sequence :',seq)
                print('api_start :', api)
                print('api :', api_list)
                sequence_dict['sequence'].append(('sequence ' + str(seq)))
                sequence_dict['api start'].append(api)
                sequence_dict['api list'].append(api_list)
                sequence_dict['which argument'].append(arg_list)
                sequence_dict['which argument index'].append(arg_index_list)
                api_list = []
                arg_list = []
                arg_index_list = []
#                 api_list.append(api)
    
    seq+=1
    index += 1
# Out:
# []
# A
# argA
# =============== LAGI DI  argA ===========
# argument 1
# argA bandingkan dengan argA
# argument 1
# argA bandingkan dengan argA
# YEY sama guys
# argument 2
# argA bandingkan dengan Nothing
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 1
# argA bandingkan dengan argA
# YEY sama guys
# argument 2
# argA bandingkan dengan numberB
# WADUH gak sama guys
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 1
# argA bandingkan dengan numberB
# WADUH gak sama guys
# argument 2
# argA bandingkan dengan Nothing
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 2
# argA bandingkan dengan Nothing
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 1
# argA bandingkan dengan argA
# argument 1
# argA bandingkan dengan argA
# YEY sama guys
# argument 2
# argA bandingkan dengan Nothing
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 1
# argA bandingkan dengan argA
# YEY sama guys
# argument 2
# argA bandingkan dengan numberB
# WADUH gak sama guys
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 1
# argA bandingkan dengan numberB
# WADUH gak sama guys
# argument 2
# argA bandingkan dengan Nothing
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 2
# argA bandingkan dengan numberB
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 1
# argA bandingkan dengan numberB
# argument 2
# argA bandingkan dengan Nothing
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# mentok bos
# sequence : 1
# api_start : A
# api : ['A', 'B', 'A', 'B']
# Nothing
# =============== LAGI DI  Nothing ===========
# SORRY ini nothing, ga bisa
# Nothing
# =============== LAGI DI  Nothing ===========
# SORRY ini nothing, ga bisa
# Nothing
# =============== LAGI DI  Nothing ===========
# SORRY ini nothing, ga bisa
# []
# B
# argA
# =============== LAGI DI  argA ===========
# index 1 ga bisa ya
# argument 1
# argA bandingkan dengan argA
# index 1 ga bisa ya
# argument 1
# argA bandingkan dengan argA
# YEY sama guys
# argument 2
# argA bandingkan dengan numberB
# WADUH gak sama guys
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 1
# argA bandingkan dengan numberB
# WADUH gak sama guys
# argument 2
# argA bandingkan dengan Nothing
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 2
# argA bandingkan dengan numberB
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# argument 1
# argA bandingkan dengan numberB
# argument 2
# argA bandingkan dengan Nothing
# argument 3
# argA bandingkan dengan Nothing
# argument 4
# argA bandingkan dengan Nothing
# mentok bos
# sequence : 2
# api_start : B
# api : ['B']
# numberB
# =============== LAGI DI  numberB ===========
# index 1 ga bisa ya
# argument 1
# numberB bandingkan dengan argA
# argument 2
# numberB bandingkan dengan numberB
# index 1 ga bisa ya
# argument 1
# numberB bandingkan dengan argA
# WADUH gak sama guys
# argument 2
# numberB bandingkan dengan numberB
# YEY sama guys
# argument 3
# numberB bandingkan dengan Nothing
# argument 4
# numberB bandingkan dengan Nothing
# argument 1
# numberB bandingkan dengan numberB
# YEY sama guys
# argument 2
# numberB bandingkan dengan Nothing
# argument 3
# numberB bandingkan dengan Nothing
# argument 4
# numberB bandingkan dengan Nothing
# argument 3
# numberB bandingkan dengan Nothing
# argument 4
# numberB bandingkan dengan Nothing
# argument 1
# numberB bandingkan dengan numberB
# index 1 ga bisa ya
# argument 1
# numberB bandingkan dengan argA
# WADUH gak sama guys
# argument 2
# numberB bandingkan dengan numberB
# YEY sama guys
# argument 3
# numberB bandingkan dengan Nothing
# argument 4
# numberB bandingkan dengan Nothing
# argument 1
# numberB bandingkan dengan numberB
# YEY sama guys
# argument 2
# numberB bandingkan dengan Nothing
# argument 3
# numberB bandingkan dengan Nothing
# argument 4
# numberB bandingkan dengan Nothing
# argument 2
# numberB bandingkan dengan Nothing
# argument 3
# numberB bandingkan dengan Nothing
# argument 4
# numberB bandingkan dengan Nothing
# mentok bos
# sequence : 2
# api_start : B
# api : ['B', 'C', 'B', 'C']
# Nothing
# =============== LAGI DI  Nothing ===========
# SORRY ini nothing, ga bisa
# Nothing
# =============== LAGI DI  Nothing ===========
# SORRY ini nothing, ga bisa
# []
# C
# numberB
# =============== LAGI DI  numberB ===========
# index 1 ga bisa ya
# index 2 ga bisa ya
# argument 1
# numberB bandingkan dengan numberB
# index 1 ga bisa ya
# index 2 ga bisa ya
# argument 1
# numberB bandingkan dengan numberB
# YEY sama guys
# argument 2
# numberB bandingkan dengan Nothing
# argument 3
# numberB bandingkan dengan Nothing
# argument 4
# numberB bandingkan dengan Nothing
# argument 2
# numberB bandingkan dengan Nothing
# argument 3
# numberB bandingkan dengan Nothing
# argument 4
# numberB bandingkan dengan Nothing
# mentok bos
# sequence : 3
# api_start : C
# api : ['C']
# Nothing
# =============== LAGI DI  Nothing ===========
# SORRY ini nothing, ga bisa
# Nothing
# =============== LAGI DI  Nothing ===========
# SORRY ini nothing, ga bisa
# Nothing
# =============== LAGI DI  Nothing ===========
# SORRY ini nothing, ga bisa

# %%
# index = 0
# seq = 1
# for api in dummy_csv['api']:
# #     index = 0
#     api_list = []
#     arg_list = []
#     arg_index_list = []
# #     api_list.append(api)
#     print(api_list)
#     print(api)
#     for args in range(total_argument):
#         arg = dummy_csv['argument ' + str(args+1)][index]
#         print('=============== LAGI DI ', arg, '===========')
#         if arg == 'Nothing':
#             print('SORRY ini nothing, ga bisa')
# #             index += 1
#             continue
#         for i in range(len(dummy_csv['argument 1'])):
#     #         print(i+1)
#             if i < index:
#                 print('index', i+1, 'ga bisa ya')
#                 continue
#     #         print(arg , dummy_csv['argument 1'][i])
#             for j in range(total_argument):
#                 print('argument ' + str(j+1))
#                 print(arg, 'bandingkan dengan', dummy_csv['argument ' + str(j+1)][i])
#                 if dummy_csv['argument ' + str(j+1)][i]=='Nothing':
#     #                 print('NOTHING nih ngab')
#                     continue
                
#                 if arg==dummy_csv['argument ' + str(j+1)][i]:
#                     api_list.append(dummy_csv['api'][i])
#                     arg_list.append('argument ' + str(j+1))
#                     arg_index_list.append(i)
#                     print('YEY sama guys')
#     #                 print(api_list)
#                 else:
#                     print('WADUH gak sama guys')
#             if i+1 ==len(dummy_csv['argument 1']):
#                 print('mentok bos')
#                 print('sequence :',seq)
#                 print('api_start :', api)
#                 print('api :', api_list)
#                 sequence_dict['sequence'].append(('sequence ' + str(seq)))
#                 sequence_dict['api start'].append(api)
#                 sequence_dict['api list'].append(api_list)
#                 sequence_dict['which argument'].append(arg_list)
#                 sequence_dict['which argument index'].append(arg_index_list)
#                 api_list = []
#                 arg_list = []
#                 arg_index_list = []
# #                 api_list.append(api)
    
#     seq+=1
#     index += 1

# %%
first_render_seq = pd.DataFrame(sequence_dict)

# %%
first_render_seq
# Out:
#      sequence api start      api list  \
# 0  sequence 1         A  [A, B, A, B]
# 1  sequence 2         B           [B]
# 2  sequence 2         B  [B, C, B, C]
# 3  sequence 3         C           [C]
#
#                                      which argument which argument index
# 0  [argument 1, argument 1, argument 1, argument 1]         [0, 1, 0, 1]
# 1                                      [argument 1]                  [1]
# 2  [argument 2, argument 1, argument 2, argument 1]         [1, 2, 1, 2]
# 3                                      [argument 1]                  [2]

# %%
# index = 0
# seq = 1

# api_list = first_render_seq["api list"]

# for arg in range(len(api_list)):
#     api_seq = []
    
# #     print(arg)
#     for i in range(len(api_list[arg])):
#         check = api_list[arg][i]
#         api_list = api_list[arg]
        
         
    
#     index+=1

# %%
labels = ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX']
incomingLabels = ['UNREAD','IMPORTANT', 'CATEGORY_PERSONAL', 'INBOX']
intersectionOfTwoArrays = list(set(incomingLabels) & set(labels))

if np.array_equal(set(labels), set(intersectionOfTwoArrays)): 
    # Do somthing 
    print("match")
# Out:
# match
